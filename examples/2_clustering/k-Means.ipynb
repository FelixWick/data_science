# %%
! pip install scikit-learn

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.decomposition import PCA
import pandas as pd

# %%
iris = load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# Using all 4 features, no target here (unsupervised)

# %%
X = iris.data

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
labels = kmeans.labels_

# %% [markdown]
# Convert to DataFrame for convenience

# %%
df = pd.DataFrame(X, columns=iris.feature_names)
df['Cluster'] = labels

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Cluster
# 0          1
# ...

# %% [markdown]
# Visualize clusters using first two features

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', marker='X', s=200, label='Centroids')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('K-Means Clustering on Iris Dataset')
plt.legend()
plt.show()

# %%
true_labels = iris.target

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], X[:, 1], c=true_labels, cmap='viridis', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', marker='X', s=200, label='Centroids')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('True Labels for Iris Dataset compared to K-Means Centroids')
plt.legend()
plt.show()

# %%
metrics.homogeneity_score(true_labels, labels)
# Out:
# 0.7364192881252849

# %%
metrics.completeness_score(true_labels, labels)
# Out:
# 0.7474865805095324

# %%
metrics.v_measure_score(true_labels, labels)
# Out:
# 0.7419116631817836

# %%
metrics.adjusted_rand_score(true_labels, labels)
# Out:
# 0.7163421126838476

# %%
metrics.adjusted_mutual_info_score(true_labels, labels)
# Out:
# 0.7386548254402865

# %%
metrics.silhouette_score(
        X,
        labels,
        metric="euclidean",
        sample_size=300,
    )
# Out:
# 0.5511916046195918

# %% [markdown]
# Visualize clusters using PCA

# %%
reduced_data = PCA(n_components=2).fit_transform(X)

# %%
plt.figure(figsize=(8,6))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=labels, cmap='viridis', s=50)
plt.title('k-Means Clustering on Iris Dataset with PCA Axes')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=true_labels, cmap='viridis', s=50)
plt.title('True Labels for Iris Dataset with PCA Axes')
plt.show()

# %% [markdown]
# Example for too many clusters chosen

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_

plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], X[:, 1], c=true_labels, cmap='viridis', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', marker='X', s=200, label='Centroids')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.title('True Labels for Iris Dataset compared to K-Means Centroids')
plt.legend()
plt.show()
