# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %%
iris = load_iris(as_frame=True)

# %%
X = iris.data
y = iris.target

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %% [markdown]
# test_size=0.95 just to get some errors:

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.95, random_state=42
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
ml_est = LogisticRegression()
ml_est.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
yhat_train = ml_est.predict(X_train)
yhat_test = ml_est.predict(X_test)

# %%
yhat_test
# Out:
# array([1, 0, 2, 2, 1, 0, 2, 2, 1, 1, 2, 0, 0, 0, 0, 2, 2, 1, 2, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 2, 0, 0, 2, 2, 0, 0, 0, 2, 2, 2, 0,
#        0, 1, 2, 2, 1, 2, 2, 2, 2, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 2, 0,
#        2, 2, 0, 1, 2, 0, 2, 2, 1, 2, 2, 1, 0, 1, 2, 0, 0, 1, 2, 0, 2, 0,
#        0, 2, 1, 2, 2, 2, 2, 1, 0, 0, 1, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 2,
#        2, 2, 2, 2, 0, 2, 2, 2, 1, 2, 2, 1, 1, 1, 0, 2, 2, 2, 0, 1, 2, 2,
#        0, 2, 0, 2, 2, 2, 2, 2, 1, 1, 2])

# %%
yhat_train_proba = ml_est.predict_proba(X_train)
yhat_test_proba = ml_est.predict_proba(X_test)

# %%
yhat_test_proba
# Out:
# array([[0.0852067 , 0.47719881, 0.43759449],
#        [0.86024644, 0.10519843, 0.03455513],
#        [0.00293707, 0.24457603, 0.7524869 ],
#        [0.08017205, 0.36168171, 0.55814625],
#        [0.05081246, 0.52661141, 0.42257612],
#        [0.76370011, 0.18934296, 0.04695693],
#        [0.16975137, 0.41272446, 0.41752417],
#        [0.01973422, 0.1806977 , 0.79956808],
#        [0.02408452, 0.63306122, 0.34285426],
#        [0.11437467, 0.52667751, 0.35894782],
#        [0.03798723, 0.18078027, 0.7812325 ],
#        [0.7173509 , 0.24860375, 0.03404535],
#        [0.82255864, 0.14991546, 0.0275259 ],
#        [0.74100755, 0.22461702, 0.03437543],
#        [0.90139299, 0.06832006, 0.03028695],
#        [0.09975267, 0.24364986, 0.65659747],
#        [0.01403603, 0.14062291, 0.84534107],
#        [0.09789199, 0.5934402 , 0.30866781],
#        [0.09599103, 0.40217315, 0.50183581],
#        [0.01274586, 0.17915473, 0.8080994 ],
#        [0.78231406, 0.17574335, 0.04194258],
#        [0.04849281, 0.23853642, 0.71297076],
#        [0.7958879 , 0.15272454, 0.05138756],
#        [0.01489915, 0.19988565, 0.7852152 ],
#        [0.0273095 , 0.1237281 , 0.84896239],
#        [0.0169824 , 0.17478107, 0.80823653],
#        [0.01256652, 0.38313444, 0.60429904],
#        [0.01348062, 0.1131131 , 0.87340628],
#        [0.69008495, 0.26251645, 0.0473986 ],
#        [0.73336805, 0.22290347, 0.04372848],
#        [0.91432685, 0.06450458, 0.02116858],
#        [0.94952823, 0.02873554, 0.02173624],
#        [0.10085571, 0.43663209, 0.4625122 ],
#        [0.83622886, 0.12689192, 0.03687921],
#        [0.82640312, 0.13850699, 0.03508989],
#        [0.01915775, 0.3718878 , 0.60895445],
#        [0.10800694, 0.3228565 , 0.56913656],
#        [0.83786365, 0.13031354, 0.03182282],
#        [0.88039396, 0.0917889 , 0.02781715],
#        [0.94852219, 0.0350956 , 0.01638221],
#        [0.0270628 , 0.23840302, 0.73453417],
#        [0.13242866, 0.1966593 , 0.67091204],
#        [0.07835196, 0.38522709, 0.53642095],
#        [0.90413659, 0.06674342, 0.02911999],
#        [0.87398427, 0.09855211, 0.02746362],
#        [0.10065279, 0.64818905, 0.25115816],
#        [0.04689404, 0.38744859, 0.56565736],
#        [0.03635845, 0.20613487, 0.75750668],
#        [0.08987841, 0.4569803 , 0.45314129],
#        [0.01246448, 0.06367798, 0.92385754],
#        [0.1269669 , 0.38931229, 0.48372081],
#        [0.00821731, 0.21220526, 0.77957743],
#        [0.10153517, 0.27379012, 0.62467471],
#        [0.85019394, 0.1199301 , 0.02987597],
#        [0.00673844, 0.29098909, 0.70227247],
#        [0.12608879, 0.55815564, 0.31575557],
#        [0.81304896, 0.15517579, 0.03177525],
#        [0.85240244, 0.11425832, 0.03333924],
#        [0.8754066 , 0.07740457, 0.04718883],
#        [0.06686488, 0.72327714, 0.20985799],
#        [0.03080705, 0.34969031, 0.61950265],
#        [0.82020143, 0.13490938, 0.04488919],
#        [0.66308896, 0.29268389, 0.04422715],
#        [0.72872691, 0.20362389, 0.06764919],
#        [0.0983199 , 0.44631138, 0.45536872],
#        [0.81671586, 0.1491812 , 0.03410294],
#        [0.16166297, 0.37533335, 0.46300369],
#        [0.01642856, 0.07687314, 0.9066983 ],
#        [0.80353301, 0.1593766 , 0.0370904 ],
#        [0.10308273, 0.46252991, 0.43438736],
#        [0.01951635, 0.25959395, 0.7208897 ],
#        [0.94803884, 0.03509478, 0.01686638],
#        [0.05245393, 0.23401804, 0.71352803],
#        [0.0270628 , 0.23840302, 0.73453417],
#        [0.0483133 , 0.76340463, 0.18828207],
#        [0.10613103, 0.24841252, 0.64545645],
#        [0.02516616, 0.07598553, 0.89884831],
#        [0.058544  , 0.59244769, 0.34900831],
#        [0.88877136, 0.0730547 , 0.03817393],
#        [0.12303283, 0.62965087, 0.24731629],
#        [0.02098145, 0.29821312, 0.68080543],
#        [0.79900793, 0.16685922, 0.03413285],
#        [0.77496835, 0.19333177, 0.03169988],
#        [0.08963229, 0.62122696, 0.28914075],
#        [0.0455155 , 0.3356441 , 0.6188404 ],
#        [0.72812426, 0.23124082, 0.04063492],
#        [0.013953  , 0.12309472, 0.86295228],
#        [0.82528971, 0.14044765, 0.03426264],
#        [0.79897518, 0.13350765, 0.06751717],
#        [0.06813355, 0.1782269 , 0.75363955],
#        [0.16822991, 0.5621073 , 0.26966279],
#        [0.0151598 , 0.1293867 , 0.8554535 ],
#        [0.03906999, 0.34477475, 0.61615526],
#        [0.03245759, 0.40381479, 0.56372763],
#        [0.00806709, 0.21458606, 0.77734685],
#        [0.08167125, 0.52013111, 0.39819763],
#        [0.71096074, 0.24517847, 0.04386079],
#        [0.79265079, 0.17789745, 0.02945176],
#        [0.02115787, 0.55215913, 0.426683  ],
#        [0.02608265, 0.2363584 , 0.73755895],
#        [0.76237846, 0.19580527, 0.04181627],
#        [0.84029003, 0.12418764, 0.03552234],
#        [0.75858864, 0.20202732, 0.03938404],
#        [0.03246129, 0.50910385, 0.45843486],
#        [0.01835232, 0.06575381, 0.91589387],
#        [0.85020015, 0.11118775, 0.0386121 ],
#        [0.01888403, 0.2059966 , 0.77511937],
#        [0.01054834, 0.05557748, 0.93387418],
#        [0.7997134 , 0.16573695, 0.03454965],
#        [0.07937467, 0.38710026, 0.53352507],
#        [0.05606485, 0.46655468, 0.47738048],
#        [0.03847245, 0.31420663, 0.64732091],
#        [0.09225208, 0.42466586, 0.48308206],
#        [0.0210566 , 0.11329884, 0.86564455],
#        [0.90552849, 0.06729273, 0.02717878],
#        [0.02232903, 0.20190046, 0.77577051],
#        [0.10964615, 0.33727726, 0.55307659],
#        [0.02794058, 0.21704201, 0.75501741],
#        [0.13865035, 0.61348103, 0.24786862],
#        [0.11503285, 0.38028071, 0.50468643],
#        [0.09594302, 0.36134497, 0.54271201],
#        [0.37855489, 0.57337763, 0.04806748],
#        [0.07808391, 0.50404413, 0.41787196],
#        [0.0888315 , 0.47697253, 0.43419597],
#        [0.88004914, 0.0924558 , 0.02749506],
#        [0.1563991 , 0.34504347, 0.49855743],
#        [0.01431881, 0.30238495, 0.68329624],
#        [0.02426524, 0.12991843, 0.84581633],
#        [0.87351767, 0.08743931, 0.03904302],
#        [0.15174595, 0.57398271, 0.27427134],
#        [0.0124288 , 0.08018094, 0.90739026],
#        [0.02930859, 0.36434981, 0.6063416 ],
#        [0.89379411, 0.08286603, 0.02333986],
#        [0.01256674, 0.11969579, 0.86773747],
#        [0.69101689, 0.26930147, 0.03968164],
#        [0.06677846, 0.39913093, 0.53409061],
#        [0.01181237, 0.33510787, 0.65307976],
#        [0.02714456, 0.23403931, 0.73881613],
#        [0.11516863, 0.43334409, 0.45148728],
#        [0.03140497, 0.24090263, 0.7276924 ],
#        [0.03427655, 0.6803448 , 0.28537865],
#        [0.09585799, 0.49550996, 0.40863205],
#        [0.03096001, 0.18646832, 0.78257166]])

# %%
cm = metrics.confusion_matrix(yhat_test, y_test)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)

disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
print(metrics.classification_report(y_test, yhat_test, target_names=iris.target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.98      0.99        48
#   versicolor       0.92      0.48      0.63        48
#    virginica       0.65      0.98      0.78        47
#
#     accuracy                           0.81       143
#    macro avg       0.86      0.81      0.80       143
# weighted avg       0.86      0.81      0.80       143
