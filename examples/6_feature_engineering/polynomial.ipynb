# %%
from sklearn.datasets import fetch_california_housing
from sklearn.preprocessing import PolynomialFeatures

# %%
X, y = fetch_california_housing(return_X_y=True, as_frame=True)

# %%
X = X[["HouseAge", "MedInc"]]

poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

print(poly.get_feature_names_out())

X_poly
# Out:
# ['HouseAge' 'MedInc' 'HouseAge^2' 'HouseAge MedInc' 'MedInc^2']
# array([[4.10000000e+01, 8.32520000e+00, 1.68100000e+03, 3.41333200e+02,
#         6.93089550e+01],
#        [2.10000000e+01, 8.30140000e+00, 4.41000000e+02, 1.74329400e+02,
#         6.89132420e+01],
#        [5.20000000e+01, 7.25740000e+00, 2.70400000e+03, 3.77384800e+02,
#         5.26698548e+01],
#        ...,
#        [1.70000000e+01, 1.70000000e+00, 2.89000000e+02, 2.89000000e+01,
#         2.89000000e+00],
#        [1.80000000e+01, 1.86720000e+00, 3.24000000e+02, 3.36096000e+01,
#         3.48643584e+00],
#        [1.60000000e+01, 2.38860000e+00, 2.56000000e+02, 3.82176000e+01,
#         5.70540996e+00]], shape=(20640, 5))
