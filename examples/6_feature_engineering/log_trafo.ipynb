# %%
import numpy as np
from sklearn.datasets import fetch_california_housing

# %%
X, y = fetch_california_housing(return_X_y=True, as_frame=True)

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
X["MedInc_log"] = np.log(X["MedInc"])
X["MedInc_1plog"] = np.log1p(X["MedInc"])  # log(1 + x)
X["MedInc_sqrt"] = np.sqrt(X["MedInc"])

# %%
X[["MedInc", "MedInc_log", "MedInc_1plog", "MedInc_sqrt"]].head()
# Out:
#    MedInc  MedInc_log  MedInc_1plog  MedInc_sqrt
# 0  8.3252    2.119287      2.232720     2.885342
# 1  8.3014    2.116424      2.230165     2.881215
# 2  7.2574    1.982022      2.111110     2.693956
# 3  5.6431    1.730434      1.893579     2.375521
# 4  3.8462    1.347086      1.578195     1.961173

# %%
X[["MedInc", "MedInc_log", "MedInc_1plog", "MedInc_sqrt"]].hist(bins=50, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'MedInc_log'}>],
#        [<Axes: title={'center': 'MedInc_1plog'}>,
#         <Axes: title={'center': 'MedInc_sqrt'}>]], dtype=object)
